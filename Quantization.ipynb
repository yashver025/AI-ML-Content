# %% [markdown]
# <a href="https://colab.research.google.com/github/yashver025/AI-ML-Content/blob/main/Quantization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Quantization = storing model weights in smaller-sized numbers (8-bit or 4-bit) instead of large numbers (32-bit) to save memory and run faster.

# %%
pip install transformers accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 9.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# "accelerate" is a Python library from Hugging Face that makes it easy to run models efficiently on GPUs, multiple GPUs, TPUs, or even CPUs—without writing complicated device-handling code.

# %%
import torch

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_name = 'gpt2'

# %% [markdown]
# # 4bit Quantization

# %%
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(model_name,
#                                              load_in_4bit=True,
#                                              bnb_4bit_compute_dtype=torch.float16,    #Even though the weights are stored in 4-bit, do the actual math using FP16.
#                                              bnb_4bit_use_double_quant=True,          #This is an optimization technique from BitsAndBytes.
#                                              device_map='auto')
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.

# %% [markdown]
# # 8bit Quantization

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name,
                                             load_in_8bit=True, #Enable 8bit Quantization
                                             device_map='auto')
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.

# %%
prompt = "Explain Machine Learning.."

# %%
inputs = tokenizer(prompt, return_tensors='pt').to(model.device)

# %%
outputs = model.generate(
    inputs.input_ids,
    max_length=50,
    temperature=0.7
)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Explain Machine Learning..
#
# The following is a list of the most popular machine learning algorithms for the past year.
#
# The following is a list of the most popular machine learning algorithms for the past year.
#
# The following is a list
